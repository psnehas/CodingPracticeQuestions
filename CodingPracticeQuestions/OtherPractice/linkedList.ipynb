# %%
class ListNode:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
class LinkedList:
    def __init__(self):
        self.head = None

    def printList(self):
        temp = self.head
        while temp:
            print(temp.data)
            temp = temp.next
    
    
    def insertAtHead(self, value):
        new_node = ListNode(value)
        new_node.next = self.head

    def insertAtEnd(self, value):
        new_node = ListNode(value)
        if not self.head:
            self.head = new_node
        node = self.head
        while node:
            node = node.next
        node.next = new_node
    
    def insertAtPosition(self,value,pos):
        new_node = ListNode(value)
        ind = 1
        node = self.head
        while ind!=pos:
            node= node.next
        new_node.next = node.next
        node.next = new_node

    def insertAfterNode(self, value, prev_node):
        new_node = ListNode(value)
        if not prev_node:
            print("Prev node is empty")
            return
        node = self.head
        while node!=prev_node:
            node=node.next
        new_node.next = node.next
        node.next = new_node

    def delete(self,node):
        # if node is the head node
        if self.head == node:
            self.head = self.head.next
        temp = self.head
        prev = None
        while temp!=node:
            prev = temp
            temp = temp.next
        # if node is somewhere in the list but not head/end
        if temp.next:
            prev.next = temp.next
        # if node is at the end of the list
        else:
            prev.next = None
    def deleteAtHead(self, node):
        self.head == self.head.next

# %%
'''
Given a list of integers, give the minimum element every time.
methods i need: insert at end, deletefromhead,

Idea behind this algo is:
1. insert the elements of the list into a linked list with a dummy head in sorted order - meaning, the lowest element is always after the dummy node.
2. whenever a getMinimum method is called, the lowest element node is popped and returned and dummy node points to the next node in the linked list.
'''
